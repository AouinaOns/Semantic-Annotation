# %%
import spacy
from keyphrase_vectorizers import KeyphraseCountVectorizer, KeyphraseTfidfVectorizer

# %%
# !pip install spacy

# %%
docs = ["""Compte rendu d’hospitalisation

Nom prénom : <nom /> <prenom />
<nom /> : Homme

Né le : 14/03/2717

Adresse : 15 <rue /> - <CP /> PARIS 15

Entrée le : 04/08/2747 Sortie le : 11/10/2747

Destinataires : Dr <nom /> ; Dr <nom />

CRH rédigé par le Dr <nom /> (interne) +Dr <nom /> 

<ville />, le 29/10/2747

Mode d’hospitalisation : SPDT

Mode d’entrée :

Patient adressé par : <hôpital />

Correspondants : Dr <nom />

Motif d’hospitalisation : Troubles du comportement avec propos délirants 

Antécédents :

Antécédents psy personnels : 

1ère hospitalisation en 2741, à l’âge de 24ans à l’hôpital <ville />, pour syndrome délirant dans un contexte de consommation de cannabis. Hospitalisation d’un mois. Rupture de soins à la sortie.

2ème hospitalisation en novembre 2742 en <ville />, puis hôpital de <ville /> pendant 1 mois pour recrudescence délirante (persécution, messianique). RISPERDAL prescrit, efficace mais rechute lors de l’arrêt du traitement suivi d’une hospitalisation à <ville /> pendant plusieurs mois.

Pendant 1 an : pas d’hospitalisation, a débuté un DAEU : Diplôme d’accès aux études universitaires, faisait du sport.

Dernière hospitalisation au <hôpital /> au secteur 16 en janvier 2744 jusqu’à mai 2744 pour syndrome délirant sur rupture de traitement. Sortie sous HALDOL 10mg.

Prise en charge à l’HDJ : accède au foyer <ville /> Capitant fin 2744.

Remplacement de l’HALDOL par l’OLANZAPINE 10mg dans l’objectif de la mise en place d’une forme retard, à l’été 2745.

Intégration au groupe NEAR fin 2745.

Intègre en mars 2746 le CRP <prenom /> <nom /> pour une formation en informatique.

Projet de déménagement lancé en mars 2747 de Capitant à un appartement thérapeutique en vue ensuite d’un HLM.

Antécédents somatiques personnels : Descente de testicules opératoire vers 4-5 ans unilatérale.

Antécédents addictologiques : 

Trouble de l’usage du cannabis.

Tabagisme.

Antécédents familiaux : 

Grand frère, mère et demi-frère ont un suivi en psychiatrie, ont été hospitalisés.

Son demi-frère a été hospitalisé pour bouffées délirantes et angoisses.

Allergies : Pollens

Eléments biographiques et mode de vie : 

Né au <pays />, à Taroudant.

En <pays /> depuis qu’il est nourrisson. Sa mère a décidé de venir en <pays /> après le divorce. 

2 frères aînés. 3 demi-frères et 1 demi-sœur côté maternel. 3 demi-sœurs côté paternel Ses frères sont arrivés à l’âge de 12 ans (avant cela père avait la garde) L’entente est bonne avec ses frères et sœurs.

Placé, intègre les orphelins d’<ville />. Son beau-père aurait un trouble de l’usage de l’alcool.

Mère gardienne d’immeuble, habite à <ville />. Frères habitent à <ville />.

Scolarité : en échec scolaire depuis CM2. Redoublement en classe de 6ème et 1ère. S’est arrêté en classe de 1ère STG (technologique).

A ensuite fait des animations à <ville /> dans des écoles primaires/maternelles pendant 1 an mais arrêt du fait d’un revenu trop bas

De 19 à 21 ans : périodes d’errances après avoir quitté le domicile du fait de violences du beau-père, il loge dans une chambre de bonne puis 115. Un ami l’héberge quelque temps, puis il intègre l’armée à 21 ans. Il fait désertion car « ne voulait pas aller en <pays /> ». Est allé vivre à <ville />. A travaillé chez Nestlé, conditionnement pendant 7 mois. Contrat interrompu car n’a pas réussi à tenir les horaires : période où fumait beaucoup de cannabis.

Portage connu de micro-organismes multi-résistants ou émergents : ☐ OUI ☒ NON 

Administration de produits sanguin labile : ☐ OUI ☒ NON

Des événements indésirables survenus pendant l’hospitalisation : ☐ OUI ☒ NON

Directives anticipées ☐ OUI ☐ NON ☒ NA"""]

# %%
nlp = spacy.load("fr_dep_news_trf")


def print_token_attributes(doc):
    for token in doc:
        print(
            f"Token: {token.text}\n"
            f"Lemma: {token.lemma_}\n"
            f"POS: {token.pos_}\n"
            f"Tag: {token.tag_}\n"
            f"Dependency: {token.dep_}\n"
            f"Shape: {token.shape_}\n"
            f"Is Alpha: {token.is_alpha}\n"
            f"Is Stop: {token.is_stop}\n"
            "-----------------------"
        )

for idx, doc_text in enumerate(docs):
    print(f"Document {idx + 1}:\n")
    doc = nlp(doc_text)
    print_token_attributes(doc)
    print("\n")

def remove_stopwords(text):
    doc = nlp(text)
    filtered_text = " ".join(token.text for token in doc if not token.is_stop)
    return filtered_text

fitred_docs=[]
for doc in docs:
    filtered_text = remove_stopwords(doc)
    fitred_docs.append(filtered_text)
# Out:
# Document 1:
#
# Token: Compte
# Lemma: compte
# POS: NOUN
# Tag: NOUN
# Dependency: ROOT
# Shape: Xxxxx
# Is Alpha: True
# Is Stop: False
# -----------------------
# Token: rendu
# Lemma: rendu
# POS: NOUN
# Tag: NOUN
# Dependency: amod
# Shape: xxxx
# Is Alpha: True
# Is Stop: False
# -----------------------
# Token: d’
# Lemma: d’
# POS: ADP
# Tag: ADP
# Dependency: case
# Shape: x’
# Is Alpha: False
# Is Stop: True
# -----------------------
# Token: hospitalisation
# Lemma: hospitalisation
# POS: NOUN
# Tag: NOUN
# Dependency: nmod
# Shape: xxxx
# Is Alpha: True
# Is Stop: False
# -----------------------
# Token:
#
#
# Lemma:
#
#
# POS: SPACE
# Tag: SPACE
# Dependency: dep
# Shape:
#
#
# Is Alpha: False
# Is Stop: False
# -----------------------
# Token: Nom
# Lemma: nom
# POS: NOUN
# Tag: NOUN
# Dependency: ROOT
# Shape: Xxx
# Is Alpha: True
# Is Stop: False
# -----------------------
# Token: prénom
# Lemma: prénom
# POS: NOUN
# Tag: NOUN
# Dependency: nmod
# Shape: xxxx
# ...

# %%
vectorizer1 = KeyphraseCountVectorizer(spacy_pipeline=nlp,pos_pattern='<ADJ.*>*<DET.*>*<NOUN.*>+<ADJ.?>')
vectorizer2 = KeyphraseTfidfVectorizer(spacy_pipeline=nlp,pos_pattern='<ADJ.*>*<DET.*>*<NOUN.*>+<ADJ.*>+')

# the following calls use the nlp object
vectorizer1.fit(docs)
vectorizer2.fit(docs)
# Out:
# KeyphraseTfidfVectorizer(pos_pattern='<ADJ.*>*<DET.*>*<NOUN.*>+<ADJ.*>+',
#                          spacy_pipeline=<spacy.lang.fr.French object at 0x1a138b350>)

# %%
# After learning the keyphrases, they can be returned.
keyphrases = vectorizer1.get_feature_names_out()
print(keyphrases)
# Out:
# ['antécédents psy' 'stabilité clinique' 'soins intensifs'
#  'délire mystique' 'un rationalisme morbide' 'idées délirantes'
#  'des propos inadaptés' 'd’ accélération psychomotrice'
#  'synthèse médicale' 'un isolement complet' 'des idées délirantes'
#  'une réticence massive' 'échec scolaire' 'des sourires immotivés'
#  'mère gardienne' 'micro-organismes multi-résistants'
#  'faible participation affective' 'une discordance idéo'
#  'd’ affect dépressif' 'propos délirants' 'evènements indésirables'
#  'testicules opératoire' 'infection nosocomiale' 'thème mystique'
#  'des éléments délirants' 'sortie médicamenteux' 'mg toutes'
#  'd’ idée suicidaire' 'l’ unité ouverte' 'schizophrénie paranoïde'
#  'ans unilatérale' 'un raisonnement mystique' 'difficultés psychiatriques'
#  'bilan hépatique' 'études universitaires' 'éducateur sportif'
#  'syndrome délirant' 'une froideur affective' 'soins libres'
#  'un mode productif' 'amélioration globale' 'des propos délirants'
# ...

# %%
keyphrases = vectorizer2.get_feature_names_out()
print(keyphrases)
# Out:
# ['stabilité clinique' 'soins intensifs' 'délire mystique'
#  'un rationalisme morbide' 'idées délirantes'
#  'toxiques urinaires négative' 'produits sanguin labile'
#  'des propos inadaptés' 'd’ accélération psychomotrice'
#  'synthèse médicale' 'un raisonnement mystique rigide'
#  'une discordance idéo - affective' 'un isolement complet'
#  'des idées délirantes' 'une réticence massive' 'échec scolaire'
#  'des sourires immotivés' 'mère gardienne'
#  'micro-organismes multi-résistants' 'faible participation affective'
#  'd’ affect dépressif' 'propos délirants' 'evènements indésirables'
#  'testicules opératoire' 'infection nosocomiale' 'thème mystique'
#  'des éléments délirants' 'sortie médicamenteux'
#  'antécédents psy personnels' 'mg toutes' 'd’ idée suicidaire'
#  'l’ unité ouverte' 'schizophrénie paranoïde' 'ans unilatérale'
#  'difficultés psychiatriques' 'bilan hépatique' 'études universitaires'
#  'éducateur sportif' 'syndrome délirant' 'une froideur affective'
# ...

# %%
# Downloads the data.
import nltk
nltk.download('stopwords')


# Using the stopwords.
from nltk.corpus import stopwords

# Initialize the stopwords
stoplist = stopwords.words('french')

# Importing libraries
from rake_nltk import Rake
from wordcloud import WordCloud
import matplotlib.pyplot as plt
  
# Initializing the Rake instance
rake = Rake(language='fr',stopwords=stoplist)
# Extracting keywords and phrases
rake.extract_keywords_from_text(docs[1])
keywords = rake.get_ranked_phrases()
  
# Displaying the keywords
print(keywords)
  
# Generate WordCloud
wordcloud = WordCloud().generate(' '.join(keywords))
  
# Display the WordCloud
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/oaouina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
import yake

language = "fr"
max_ngram_size = 4
deduplication_threshold = 0.9
deduplication_algo = 'seqm'
windowSize = 1
numOfKeywords = 20

custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, dedupFunc=deduplication_algo, windowsSize=windowSize, top=numOfKeywords, features=None)


for doc in fitred_docs:
    keywords = custom_kw_extractor.extract_keywords(doc)
    for kw in keywords:
        print(kw)
# Out:
# ('Intégration groupe NEAR fin', 2.286631716712683e-05)
# ('Diplôme accès études universitaires', 4.2242052721982656e-05)
# ('syndrome délirant rupture traitement', 6.707132766417567e-05)
# ('syndrome délirant contexte consommation', 7.141448367945451e-05)
# ('délirant contexte consommation cannabis', 9.212115669771777e-05)
# ('mise place forme retard', 9.50274864328143e-05)
# ('efficace rechute arrêt traitement', 0.00011168531208386721)
# ('objectif mise place forme', 0.00012181905099983404)
# ('Remplacement HALDOL OLANZAPINE', 0.0001391371085957703)
# ('rechute arrêt traitement suivi', 0.00014321400207345305)
# ('arrêt traitement suivi hospitalisation', 0.0002116321165349626)
# ('Prise charge HDJ', 0.000228315268169778)
# ('Intégration groupe NEAR', 0.0002777794012131211)
# ('groupe NEAR fin', 0.0004850210607878104)
# ('Diplôme accès études', 0.0005105920337691981)
# ('syndrome délirant rupture', 0.0005392195334616153)
# ('syndrome délirant contexte', 0.0006733334767351774)
# ...

# %%
text="""
Compte rendu d’hospitalisation

Nom prénom : <nom /> <prenom />
<nom /> : Homme

Né le : 14/03/2717

Adresse : 15 <rue /> - <CP /> PARIS 15

Entrée le : 04/08/2747 Sortie le : 11/10/2747

Destinataires : Dr <nom /> ; Dr <nom />

CRH rédigé par le Dr <nom /> (interne) +Dr <nom />

<ville />, le 29/10/2747

Mode d’hospitalisation : SPDT

Mode d’entrée :

Patient adressé par : <hôpital />

Correspondants : Dr <nom />

Motif d’hospitalisation : Troubles du comportement avec propos délirants

Antécédents :

Antécédents psy personnels :

1ère hospitalisation en 2741, à l’âge de 24ans à l’hôpital <ville />, pour syndrome délirant dans un contexte de consommation de cannabis. Hospitalisation d’un mois. Rupture de soins à la sortie.

2ème hospitalisation en novembre 2742 en <ville />, puis hôpital de <ville /> pendant 1 mois pour recrudescence délirante (persécution, messianique). RISPERDAL prescrit, efficace mais rechute lors de l’arrêt du traitement suivi d’une hospitalisation à <ville /> pendant plusieurs mois.

Pendant 1 an : pas d’hospitalisation, a débuté un DAEU : Diplôme d’accès aux études universitaires, faisait du sport.

Dernière hospitalisation au <hôpital /> au secteur 16 en janvier 2744 jusqu’à mai 2744 pour syndrome délirant sur rupture de traitement. Sortie sous HALDOL 10mg.

Prise en charge à l’HDJ : accède au foyer <ville /> Capitant fin 2744.

Remplacement de l’HALDOL par l’OLANZAPINE 10mg dans l’objectif de la mise en place d’une forme retard, à l’été 2745.

Intégration au groupe NEAR fin 2745.

Intègre en mars 2746 le CRP <prenom /> <nom /> pour une formation en informatique.

Projet de déménagement lancé en mars 2747 de Capitant à un appartement thérapeutique en vue ensuite d’un HLM.

Antécédents somatiques personnels : Descente de testicules opératoire vers 4-5 ans unilatérale.

Antécédents addictologiques :

Trouble de l’usage du cannabis.

Tabagisme.

Antécédents familiaux :

Grand frère, mère et demi-frère ont un suivi en psychiatrie, ont été hospitalisés.

Son demi-frère a été hospitalisé pour bouffées délirantes et angoisses.

Allergies : Pollens

Eléments biographiques et mode de vie :

Né au <pays />, à Taroudant.

En <pays /> depuis qu’il est nourrisson. Sa mère a décidé de venir en <pays /> après le divorce.

2 frères aînés. 3 demi-frères et 1 demi-sœur côté maternel. 3 demi-sœurs côté paternel Ses frères sont arrivés à l’âge de 12 ans (avant cela père avait la garde) L’entente est bonne avec ses frères et sœurs.

Placé, intègre les orphelins d’<ville />. Son beau-père aurait un trouble de l’usage de l’alcool.

Mère gardienne d’immeuble, habite à <ville />. Frères habitent à <ville />.

Scolarité : en échec scolaire depuis CM2. Redoublement en classe de 6ème et 1ère. S’est arrêté en classe de 1ère STG (technologique).

Conclusion : Patient de 30 ans ayant présenté une rechute sur un mode productif avec délire mystique dans un contexte de rupture de traitement et de consommation de cannabis. Amélioration globale de l’état clinique sous ZYPADHERA. Retour à domicile avec reprise des projets professionnels dans un second temps.

Docteur <nom /> (assistante spécialiste)

Infection nosocomiale : ☐ OUI ☒ NON

Portage connu de micro-organismes multi-résistants ou émergents : ☐ OUI ☒ NON

Administration de produits sanguin labile : ☐ OUI ☒ NON

Des événements indésirables survenus pendant l’hospitalisation : ☐ OUI ☒ NON

Directives anticipées ☐ OUI ☐ NON ☒ NA
"""

# %%
from keybert import KeyBERT
from flair.embeddings import TransformerDocumentEmbeddings

# Init KeyBERT
kw_model = KeyBERT(model=TransformerDocumentEmbeddings('camembert-base'))
kw_model.extract_keywords(docs=docs, vectorizer=KeyphraseCountVectorizer(spacy_pipeline='fr_dep_news_trf', pos_pattern='<ADJ.?>*<NOUN.*>+<ADJ.?>', stop_words='french'))
# Out:
# [('recrudescence délirante', 0.7886),
#  ('antécédents addictologiques', 0.786),
#  ('antécédents somatiques', 0.7828),
#  ('schizophrénie paranoïde', 0.778),
#  ('antécédents psy', 0.7756)]

# %%
# Init vectorizer for the German language
vectorizer = KeyphraseCountVectorizer(spacy_pipeline='fr_dep_news_trf', pos_pattern='<ADJ.*>*<DET.*>*<NOUN.*>+<ADJ.*>*')

# Get German keyphrases
kw_model.extract_keywords(docs=docs, vectorizer=vectorizer)
# Out:
# [('recrudescence délirante', 0.7886),
#  ('antécédents addictologiques', 0.786),
#  ('antécédents somatiques', 0.7828),
#  ('schizophrénie paranoïde', 0.778),
#  ('antécédents psy', 0.7756)]

# %%
keyphrases = vectorizer1.get_feature_names_out()
print(keyphrases)
# Out:
# ['antécédents psy' 'stabilité clinique' 'soins intensifs'
#  'délire mystique' 'un rationalisme morbide' 'idées délirantes'
#  'des propos inadaptés' 'd’ accélération psychomotrice'
#  'synthèse médicale' 'un isolement complet' 'des idées délirantes'
#  'une réticence massive' 'échec scolaire' 'des sourires immotivés'
#  'mère gardienne' 'micro-organismes multi-résistants'
#  'faible participation affective' 'une discordance idéo'
#  'd’ affect dépressif' 'propos délirants' 'evènements indésirables'
#  'testicules opératoire' 'infection nosocomiale' 'thème mystique'
#  'des éléments délirants' 'sortie médicamenteux' 'mg toutes'
#  'd’ idée suicidaire' 'l’ unité ouverte' 'schizophrénie paranoïde'
#  'ans unilatérale' 'un raisonnement mystique' 'difficultés psychiatriques'
#  'bilan hépatique' 'études universitaires' 'éducateur sportif'
#  'syndrome délirant' 'une froideur affective' 'soins libres'
#  'un mode productif' 'amélioration globale' 'des propos délirants'
# ...

# %%
def find_chunks_with_regex(text, chunk):
    matched_spans = []

    pattern = re.compile(chunk, re.IGNORECASE)
    for match in re.finditer(pattern, text.lower()):
            start, end = match.span()
            matched_text = text[start:end]
            matched_spans.append((matched_text, start, end))


    return matched_spans

# %%
for kp in keyphrases:
        print(find_chunks_with_regex(docs[0],kp))
        list_matches.extend(find_chunks_with_regex(docs[0],kp))
# Out:
# [('ENTITY', 510, 525, 'Antécédents psy')]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 for kp in keyphrases:
#       2         print(find_chunks_with_regex(docs[0],kp))
# ----> 3         list_matches.extend(find_chunks_with_regex(docs[0],kp))
#
# NameError: name 'list_matches' is not defined

# %%
# Init vectorizer for the German language
vectorizer = KeyphraseCountVectorizer(spacy_pipeline='fr_dep_news_trf', pos_pattern='<VERB.*>*<DET.?>*<NOUN.*>*<ADJ.?>')

# Get German keyphrases
kw_model.extract_keywords(docs=docs, vectorizer=vectorizer)
# Out:
# [('recrudescence délirante', 0.7886),
#  ('antécédents addictologiques', 0.786),
#  ('antécédents somatiques', 0.7828),
#  ('schizophrénie paranoïde', 0.778),
#  ('antécédents psy', 0.7756)]

# %%
text = """Compte rendu d’hospitalisation

Nom prénom : <nom /> <prenom />
<nom /> : Homme

Né le : 14/03/2717

Adresse : 15 <rue /> - <CP /> PARIS 15

Entrée le : 04/08/2747 Sortie le : 11/10/2747

Destinataires : Dr <nom /> ; Dr <nom />

CRH rédigé par le Dr <nom /> (interne) +Dr <nom /> 

<ville />, le 29/10/2747

Mode d’hospitalisation : SPDT

Mode d’entrée :

Patient adressé par : <hôpital />

Correspondants : Dr <nom />

Motif d’hospitalisation : Troubles du comportement avec propos délirants 

Antécédents :

Antécédents psy personnels : 

1ère hospitalisation en 2741, à l’âge de 24ans à l’hôpital <ville />, pour syndrome délirant dans un contexte de consommation de cannabis. Hospitalisation d’un mois. Rupture de soins à la sortie.

2ème hospitalisation en novembre 2742 en <ville />, puis hôpital de <ville /> pendant 1 mois pour recrudescence délirante (persécution, messianique). RISPERDAL prescrit, efficace mais rechute lors de l’arrêt du traitement suivi d’une hospitalisation à <ville /> pendant plusieurs mois.

Pendant 1 an : pas d’hospitalisation, a débuté un DAEU : Diplôme d’accès aux études universitaires, faisait du sport.

Dernière hospitalisation au <hôpital /> au secteur 16 en janvier 2744 jusqu’à mai 2744 pour syndrome délirant sur rupture de traitement. Sortie sous HALDOL 10mg.

Prise en charge à l’HDJ : accède au foyer <ville /> Capitant fin 2744.

Remplacement de l’HALDOL par l’OLANZAPINE 10mg dans l’objectif de la mise en place d’une forme retard, à l’été 2745.

Intégration au groupe NEAR fin 2745.

Intègre en mars 2746 le CRP <prenom /> <nom /> pour une formation en informatique.

Projet de déménagement lancé en mars 2747 de Capitant à un appartement thérapeutique en vue ensuite d’un HLM.

Antécédents somatiques personnels : Descente de testicules opératoire vers 4-5 ans unilatérale.

Antécédents addictologiques : 

Trouble de l’usage du cannabis.

Tabagisme.

Antécédents familiaux : 

Grand frère, mère et demi-frère ont un suivi en psychiatrie, ont été hospitalisés.

Son demi-frère a été hospitalisé pour bouffées délirantes et angoisses.

Allergies : Pollens

Eléments biographiques et mode de vie : 

Né au <pays />, à Taroudant.

En <pays /> depuis qu’il est nourrisson. Sa mère a décidé de venir en <pays /> après le divorce. 

2 frères aînés. 3 demi-frères et 1 demi-sœur côté maternel. 3 demi-sœurs côté paternel Ses frères sont arrivés à l’âge de 12 ans (avant cela père avait la garde) L’entente est bonne avec ses frères et sœurs.

Placé, intègre les orphelins d’<ville />. Son beau-père aurait un trouble de l’usage de l’alcool.

Resectorisation sur le S14 suite à un déménagement

Examens complémentaires à réaliser en externe ☐ OUI ☒ NON

Programme de soin : ☐ OUI ☒ NON

Retour à domicile : ☒ OUI ☐ NON

Conclusion : Patient de 30 ans ayant présenté une rechute sur un mode productif avec délire mystique dans un contexte de rupture de traitement et de consommation de cannabis. Amélioration globale de l’état clinique sous ZYPADHERA. Retour à domicile avec reprise des projets professionnels dans un second temps.

Docteur <nom /> (assistante spécialiste)

Infection nosocomiale : ☐ OUI ☒ NON

Portage connu de micro-organismes multi-résistants ou émergents : ☐ OUI ☒ NON 

Administration de produits sanguin labile : ☐ OUI ☒ NON

Des événements indésirables survenus pendant l’hospitalisation : ☐ OUI ☒ NON

Directives anticipées ☐ OUI ☐ NON ☒ NA"""  # Spelling errors intentional.

# %%
import spacy
from spaczz.matcher import SimilarityMatcher
from spacy.tokens import Span
from spacy.matcher import PhraseMatcher

file_path="/Users/oaouina/Applications/pythonProject/KeyphraseVectorizers/annotation_art1.txt"
# Read the lines from the text file and put them into a list
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Remove leading and trailing whitespace from each line and create the list
entities_list = [line.strip() for line in lines]

nlp = spacy.load("fr_core_news_lg")
doc = nlp(text)

matcher = PhraseMatcher(nlp.vocab, attr="LEMMA")

# Iterate over the patterns and add them to the Matcher
for pattern in entities_list:
    matcher.add("ENTITY", [nlp(pattern.lower())])

# %%
matches = matcher(doc)
matches
# Out:
# [(17590775310403619837, 3, 4),
#  (17590775310403619837, 48, 49),
#  (17590775310403619837, 96, 97),
#  (17590775310403619837, 98, 99),
#  (17590775310403619837, 105, 106),
#  (17590775310403619837, 124, 125),
#  (17590775310403619837, 126, 129),
#  (17590775310403619837, 126, 130),
#  (17590775310403619837, 130, 132),
#  (17590775310403619837, 131, 132),
#  (17590775310403619837, 133, 134),
#  (17590775310403619837, 136, 137),
#  (17590775310403619837, 136, 138),
#  (17590775310403619837, 142, 143),
#  (17590775310403619837, 160, 162),
#  (17590775310403619837, 161, 162),
#  (17590775310403619837, 163, 169),
#  (17590775310403619837, 166, 167),
#  (17590775310403619837, 166, 169),
#  (17590775310403619837, 168, 169),
#  (17590775310403619837, 170, 171),
#  (17590775310403619837, 184, 185),
#  (17590775310403619837, 205, 206),
#  (17590775310403619837, 205, 207),
#  (17590775310403619837, 206, 207),
#  (17590775310403619837, 213, 214),
#  (17590775310403619837, 214, 215),
# ...

# %%
from typing import Iterable, List, Set

class Span:
    def __init__(self, entity_type, start, end, text):
        self.entity_type = entity_type
        self.start = start
        self.end = end
        self.text = text

def filter_spans(spans: Iterable[Span]) -> List[Span]:
    """Filter a sequence of spans and remove duplicates or overlaps. Useful for
    creating named entities (where one token can only be part of one entity) or
    when merging spans with `Retokenizer.merge`. When spans overlap, the (first)
    longest span is preferred over shorter spans.

    spans (Iterable[Span]): The spans to filter.
    RETURNS (List[Span]): The filtered spans.
    """
    get_sort_key = lambda span: (span.end - span.start, -span.start)
    sorted_spans = sorted(spans, key=get_sort_key, reverse=True)
    result = []
    seen_tokens: Set[int] = set()
    for span in sorted_spans:
        # Check for end - 1 here because boundaries are inclusive
        if span.start not in seen_tokens and span.end - 1 not in seen_tokens:
            result.append(span)
            seen_tokens.update(range(span.start, span.end))
    result = sorted(result, key=lambda span: span.start)
    return result


def convert_to_brat_ann(spans):
    lines = []
    for idx, span in enumerate(spans, start=1):
        entity_type = span.entity_type
        start = span.start
        end = span.end  # End position is exclusive in spaCy
        text = span.text
        line = f'T{idx}\t{entity_type} {start} {end}\t{text}\n'
        lines.append(line)
    return ''.join(lines)


    

    


spans=[]
for match_id, start, end in matches:
    span = doc[start: end]
    print(span.text, span.start_char, span.end_char)
    spans.append(("ENTITY", span.start_char, span.end_char,span.text))
    



spans_class=[Span(*span) for span in spans]
# Apply filter_spans function
filtered_spans = filter_spans(spans_class)

# Print the filtered spans with the same format
for span in filtered_spans:
    print((span.entity_type, span.start, span.end, span.text))
# Out:
# hospitalisation 15 30
# Sortie 164 170
# hospitalisation 315 330
# SPDT 333 337
# Patient 356 363
# hospitalisation 428 443
# Troubles du comportement 446 470
# Troubles du comportement avec 446 475
# propos délirants 476 492
# délirants 483 492
# Antécédents 495 506
# Antécédents 510 521
# Antécédents psy 510 525
# hospitalisation 546 561
# syndrome délirant 616 633
# délirant 625 633
# un contexte de consommation de cannabis 639 678
# consommation 654 666
# consommation de cannabis 654 678
# cannabis 670 678
# Hospitalisation 680 695
# hospitalisation 743 758
# recrudescence 836 849
# recrudescence délirante 836 859
# délirante 850 859
# RISPERDAL 888 897
# prescrit 898 906
# efficace 908 916
# rechute 922 929
# arrêt 940 945
# arrêt du traitement 940 959
# traitement 949 959
# suivi 960 965
# suivi d’une hospitalisation 960 987
# hospitalisation 972 987
# hospitalisation 1046 1061
# Dernière hospitalisation 1144 1168
# hospitalisation 1153 1168
# syndrome délirant 1236 1253
# ...

# %%
from keybert import KeyBERT
from flair.embeddings import TransformerDocumentEmbeddings

# Init KeyBERT
kw_model = KeyBERT(model=TransformerDocumentEmbeddings('camembert-base'))
kw_model.extract_keywords(docs=docs, vectorizer=KeyphraseCountVectorizer(spacy_pipeline='fr_dep_news_trf', pos_pattern='<ADJ.?>*<NOUN.*>+<ADJ.?>', stop_words='french'))
# Out:
# [('recrudescence délirante', 0.7886),
#  ('antécédents addictologiques', 0.786),
#  ('antécédents somatiques', 0.7828),
#  ('schizophrénie paranoïde', 0.778),
#  ('antécédents psy', 0.7756)]

# %%
# Init vectorizer for the German language
vectorizer = KeyphraseCountVectorizer(spacy_pipeline='fr_dep_news_trf', pos_pattern='<ADJ.*>*<DET.*>*<NOUN.*>+<ADJ.*>*')

# Get German keyphrases
kw_model.extract_keywords(docs=docs, vectorizer=vectorizer)
# Out:
# [('recrudescence délirante', 0.7886),
#  ('antécédents addictologiques', 0.786),
#  ('schizophrénie paranoïde', 0.778),
#  ('sérologies vih', 0.7766),
#  ('antécédents psy personnels', 0.7727)]

# %%
keyphrases = vectorizer1.get_feature_names_out()
print(keyphrases)
# Out:
# ['antécédents psy' 'stabilité clinique' 'soins intensifs'
#  'délire mystique' 'un rationalisme morbide' 'idées délirantes'
#  'des propos inadaptés' 'd’ accélération psychomotrice'
#  'synthèse médicale' 'un isolement complet' 'des idées délirantes'
#  'une réticence massive' 'échec scolaire' 'des sourires immotivés'
#  'mère gardienne' 'micro-organismes multi-résistants'
#  'faible participation affective' 'une discordance idéo'
#  'd’ affect dépressif' 'propos délirants' 'evènements indésirables'
#  'testicules opératoire' 'infection nosocomiale' 'thème mystique'
#  'des éléments délirants' 'sortie médicamenteux' 'mg toutes'
#  'd’ idée suicidaire' 'l’ unité ouverte' 'schizophrénie paranoïde'
#  'ans unilatérale' 'un raisonnement mystique' 'difficultés psychiatriques'
#  'bilan hépatique' 'études universitaires' 'éducateur sportif'
#  'syndrome délirant' 'une froideur affective' 'soins libres'
#  'un mode productif' 'amélioration globale' 'des propos délirants'
# ...

# %%
import re
# Function to normalize apostrophes
def normalize_apostrophes(text):
    return re.sub(r"’ ", "'", text)

def find_chunks_with_regex(text, chunk):
    matched_spans = []

    pattern = re.compile(chunk, re.IGNORECASE)
    for match in re.finditer(pattern, text):
            start, end = match.span()
            matched_text = text[start:end]
            matched_spans.append(("ENTITY", start, end,matched_text))


    return matched_spans

for kp in keyphrases:
        if not find_chunks_with_regex(docs[0],kp):
            print(kp)
        spans.extend(find_chunks_with_regex(docs[0],kp))
# Out:
# d’ accélération psychomotrice
# d’ affect dépressif
# d’ idée suicidaire
# l’ unité ouverte
# l’ état clinique
# l’ éducation thérapeutique
# l’ entrée positifs
# l’ acte auto-agressif

# %%
spans_class=[Span(*span) for span in spans]
# Apply filter_spans function
filtered_spans = filter_spans(spans_class)

# Print the filtered spans with the same format
for span in filtered_spans:
    print((span.entity_type, span.start, span.end, span.text))
# Out:
# ('ENTITY', 15, 30, 'hospitalisation')
# ('ENTITY', 164, 170, 'Sortie')
# ('ENTITY', 315, 330, 'hospitalisation')
# ('ENTITY', 333, 337, 'SPDT')
# ('ENTITY', 356, 363, 'Patient')
# ('ENTITY', 428, 443, 'hospitalisation')
# ('ENTITY', 446, 475, 'Troubles du comportement avec')
# ('ENTITY', 476, 492, 'propos délirants')
# ('ENTITY', 495, 506, 'Antécédents')
# ('ENTITY', 510, 525, 'Antécédents psy')
# ('ENTITY', 546, 561, 'hospitalisation')
# ('ENTITY', 616, 633, 'syndrome délirant')
# ('ENTITY', 639, 678, 'un contexte de consommation de cannabis')
# ('ENTITY', 680, 695, 'Hospitalisation')
# ('ENTITY', 743, 758, 'hospitalisation')
# ('ENTITY', 836, 859, 'recrudescence délirante')
# ('ENTITY', 888, 897, 'RISPERDAL')
# ('ENTITY', 898, 906, 'prescrit')
# ('ENTITY', 908, 916, 'efficace')
# ('ENTITY', 922, 929, 'rechute')
# ('ENTITY', 940, 959, 'arrêt du traitement')
# ('ENTITY', 960, 987, 'suivi d’une hospitalisation')
# ('ENTITY', 1046, 1061, 'hospitalisation')
# ...

# %%
brat_ann = convert_to_brat_ann(filtered_spans)

# Write to .ann file
with open('/Users/oaouina/Applications/pythonProject/KeyphraseVectorizers/document.ann', 'w', encoding='utf-8') as ann_file:
    ann_file.write(brat_ann)

# %%
# Write to .ann file
with open('KeyphraseVectorizers/document.txt', 'w', encoding='utf-8') as txt_file:
    txt_file.write(text)
